# %% [markdown]
# <a href="https://colab.research.google.com/github/zxs1652/zcq/blob/master/manim%E4%BD%BF%E7%94%A8%E8%A7%84%E8%8C%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [56.8 kB]
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# ...

# %%
from manim import *
# Out:
# Manim Community v0.6.0

# %%
ShowCreationThenDestructionAround
# Out:
# manim.animation.indication.ShowCreationThenDestructionAround

# %%
# %%manim  -qm -v WARNING ManimCELogo
#
# class ManimCELogo(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         logo_green = "#87c2a5"
#         logo_blue = "#525893"
#         logo_red = "#e07a5f"
#         logo_black = "#343434"
#         ds_m = MathTex(r"\mathbb{M}", fill_color=logo_black).scale(7)
#         ds_m.shift(2.25 * LEFT + 1.5 * UP)
#         circle = Circle(color=logo_green, fill_opacity=1).shift(LEFT)
#         square = Square(color=logo_blue, fill_opacity=1).shift(UP)
#         triangle = Triangle(color=logo_red, fill_opacity=1).shift(RIGHT)
#         logo = VGroup(triangle, square, circle, ds_m)  # order matters
#         logo.move_to(ORIGIN)
#         self.add(logo)

# %%
# %%manim -v WARNING --disable_caching -pql -s Example1
#
# class Example1(Scene):
#     def construct(self):
#         self.add(Circle())

# %%
import pkg_resources

from manim import *

version_num = pkg_resources.get_distribution("manim").version

# %%
# %%manim  -qm  -v WARNING TwitterScene
# class TwitterScene(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         version = Tex(f"v{version_num}").to_corner(UR).set_color(BLACK)
#         self.add(version)
#         ## add twitter scene content here
#
#         banner = ManimBanner(dark_theme=False).scale(0.3).to_corner(DR)
#         self.play(FadeIn(banner))
#         self.play(banner.expand())
#         self.play(FadeOut(banner))

# %%
Tex('The horse does not eat cucumber salad.')
Tex(f"v{version_num}").to_corner(UR).set_color(BLACK)
# Out:
# Tex('v0.6.0')

# %%
# %%manim  -qm -v WARNING BraceAnnotation
# class BraceAnnotation(Scene):
#     def construct(self):
#         dot = Dot([-2, -1, 0])
#         dot2 = Dot([2, 1, 0])
#         line = Line(dot.get_center(), dot2.get_center()).set_color(ORANGE)
#         b1 = Brace(line)
#         b1text = b1.get_text("Horizontal distance")
#         b2 = Brace(line, direction=line.copy().rotate(PI / 2).get_unit_vector())
#         b2text = b2.get_tex("x-x_1")
#         self.add(line, dot, dot2, b1, b2, b1text, b2text)

# %%
# %%manim  -sqm -v WARNING SquareToCircle
# config.media_width = "75%"#调节输出MP4/gif大小
# class SquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()
#         square = Square()
#         square.flip(RIGHT)
#         square.rotate(-3 * TAU / 8)
#         circle.set_fill(PINK, opacity=0.5)
#
#         self.play(Create(square))
#         self.play(Transform(square, circle))
#         #self.play(FadeOut(square))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-75-c9a4dd1d76ce> in <module>
# ----> 1 get_ipython().run_cell_magic('manim', ' -qm  -n 0,10 -c WHITE SquareToCircle', 'config.media_width = "75%"#调节输出MP4/gif大小\nclass SquareToCircle(Scene):\n    def construct(self):\n        circle = Circle()\n        square = Square()\n        square.flip(RIGHT)\n        square.rotate(-3 * TAU / 8)\n        circle.set_fill(PINK, opacity=0.5)\n\n        self.play(Create(square))\n        self.play(Transform(square, circle))\n        #self.play(FadeOut(square))\n')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2401             with self.builtin_trap:
#    2402                 args = (magic_arg_s, cell)
# -> 2403                 result = fn(*args, **kwargs)
#    2404             return result
#    2405
# ...

# %%
from manim import *

# %%
# %%manim?
# #获取帮助命令

# %%
# %%manim -i -qm -v WARNING MovingFrameBox
#
# class MovingFrameBox(Scene):
#     def construct(self):
#         text=MathTex(
#             "\\frac{d}{dx}f(x)g(x)=","f(x)\\frac{d}{dx}g(x)","+",
#             "g(x)\\frac{d}{dx}f(x)"
#         )
#         self.play(Write(text))
#         framebox1 = SurroundingRectangle(text[1], buff = .1)
#         framebox2 = SurroundingRectangle(text[3], buff = .1)
#         self.play(
#             Create(framebox1),
#         )
#         self.wait()
#         self.play(
#             ReplacementTransform(framebox1,framebox2),
#         )
#         self.wait()
# Out:
# [05/10/21 07:10:58] WARNING  --save_as_gif is deprecated, please  commands.py:85
#                              use --format=gif instead!

# %%
# %%manim  -qm -v WARNING UpdatersExample
#
# class UpdatersExample(Scene):
#     def construct(self):
#         decimal = DecimalNumber(
#             0,
#             show_ellipsis=True,
#             num_decimal_places=3,
#             include_sign=True,
#         )
#         square = Square().to_edge(UP)
#
#         decimal.add_updater(lambda d: d.next_to(square, RIGHT))
#         decimal.add_updater(lambda d: d.set_value(square.get_center()[1]))
#         self.add(square, decimal)
#         self.play(
#             square.animate.to_edge(DOWN),
#             rate_func=there_and_back,
#             run_time=5,
#         )
#         self.wait()
# Out:
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim  -iqm -v WARNING ExampleRotation
# #-iqm 生成gif
# #-pqm或者qm生成MP4
# class ExampleRotation(Scene):
#     def construct(self):
#         self.camera.background_color = WHITE
#         m1a = Square().set_color(RED).shift(LEFT)
#         m1b = Circle().set_color(RED).shift(LEFT)
#         m2a= Square().set_color(BLUE).shift(RIGHT)
#         m2b= Circle().set_color(BLUE).shift(RIGHT)
#         m3a= Square().set_color(GREEN).shift(3*RIGHT)
#         m3b= Circle().set_color(GREEN).shift(3*RIGHT)
#
#         points = m2a.points
#         points = np.roll(points, int(len(points)/4), axis=0)
#         m2a.points = points
#
#         self.play(Transform(m1a,m1b),Transform(m2a,m2b), run_time=1)
# Out:
# [05/10/21 06:46:48] WARNING  --save_as_gif is deprecated, please  commands.py:85
#                              use --format=gif instead!

# %% [markdown]
# 以下是manim社区版本，生成的文件保存在相应路径下

# %%
import manim

# %%
# %cd media/project
# Out:
# /content/media/project

# %%
# %%manim  -iqm -v WARNING xidianlogo
# class xidianlogo(Scene):
#     def construct(self):
#       self.camera.background_color = WHITE
#       self.camera.background_color = "#ece6e2"
#       #self.camera.set_background()
#       img=ImageMobject('xidian.jpg')
#       self.add(img)
#       img.scale(0.3)
#       img.stretch(factor=1.2,dim=1)
#       img.to_corner(UL)
#       p1=np.array([-1,0,0])
#       p2=np.array([1,0,0])
#       p3=np.array([0,2,0])
#       p4=np.array([0,-2,0])
#       shape=Polygon(p1,p3,p2,p4)
#       shape1=Polygon(p1,p3,p2,p4)
#       shape2=Polygon(p1,p3,p2,p4)
#       shape3=Polygon(p1,p3,p2,p4)
#       shape4=Polygon(p1,p3,p2,p4)
#       shape5=Polygon(p1,p3,p2,p4)
#       shape6=Polygon(p1,p3,p2,p4)
#       shape7=Polygon(p1,p3,p2,p4)
#       shape1.next_to(shape,buff=0)
#       shape2.next_to(shape1,buff=0)
#       shape3.next_to(shape2,buff=0)
#       shape4.next_to(shape3,buff=0)
#       shape5.next_to(shape4,buff=0)
#       shape6.next_to(shape5,buff=0)
#       shape7.next_to(shape6,buff=0)
#       vg=VGroup(shape,shape1,shape2,shape3,shape4,shape5,shape6,shape7)
#       self.add(vg)
#       vg.scale(0.5)
#       vg.shift(LEFT*5)
#       for i in range(0,8):
#         vg[i].shift(UP*i/2)
#
#
#
#       #img.rotatie(90*DEGREES,axis=IN)
#       #self.play(FadeOut(img))
# Out:
# [05/11/21 04:37:45] WARNING  --save_as_gif is deprecated, please  commands.py:85
#                              use --format=gif instead!

# %%
# %%manim  -iqm -v WARNING xidianlogo
# class xidianlogo(Scene):
#     def construct(self):
#       self.camera.background_color = WHITE
#       self.camera.background_color = "#ece6e2"
#       #self.camera.set_background()
#       img=ImageMobject('xidian.jpg')
#       self.add(img)
#       img.scale(0.3)
#       img.stretch(factor=1.2,dim=1)
#       img.to_corner(UL)
#       p1=np.array([-1,0,0])
#       p2=np.array([1,0,0])
#       p3=np.array([0,2,0])
#       p4=np.array([0,-2,0])
#       shape=Polygon(p1,p3,p2,p4)
#       shape1=Polygon(p1,p3,p2,p4)
#       shape1.next_to(shape,UR,buff=0)
#       shape1.shift(DL)
#       shape1.shift(DOWN)
#
#       shape2=Polygon(p1,p3,p2,p4)
#       shape3=Polygon(p1,p3,p2,p4)
#       shape3.next_to(shape,UR,buff=0)
#       shape3.shift(DL)
#       shape3.shift(DOWN)
#
#       vg=VGroup(shape,shape1)
#       vg1=VGroup(shape2,shape3).shift(UR*3)
#       vg3=VGroup(shape,shape1)
#       vg3.shift(UR)
#       vgg=VGroup(vg,vg1,vg3)
#       self.add(vgg)
#       vgg.scale(0.2)
#       #axis=Axes()
#       #self.add(axis)
#       #vg.shift(LEFT*5)
#      # for i in range(0,8):
#       #  vg[i].shift(UP*i/2)
#
#
#
#       #img.rotatie(90*DEGREES,axis=IN)
#       #self.play(FadeOut(img))
# Out:
# [05/11/21 05:20:53] WARNING  --save_as_gif is deprecated, please  commands.py:85
#                              use --format=gif instead!

# %%
# %cd /content/media/project/
# Out:
# /content/media/project

# %%
# %%manim  -pqm -v WARNING xidianlogo
# config.media_width = "75%"#调节输出MP4/gif大小
# class xidianlogo(Scene):
#     def construct(self):
#       self.camera.background_color = WHITE
#
#       self.camera.background_color = "#ece6e2"
#       #self.camera.set_background()
#       img=ImageMobject('xidian.jpg')
#       self.add(img)
#       img.scale(0.3)
#       img.stretch(factor=1.2,dim=1)
#       img.to_corner(UL)
#       line1=Line(np.array([-2,0,0]),np.array([0,-4,0])).set_color(BLACK)
#       line2=Line(np.array([-1.75,0.5,0]),np.array([0.25,-3.5,0])).set_color(BLACK)
#       line3=Line(np.array([-1.5,1,0]),np.array([0.5,-3,0])).set_color(BLACK)
#       line4=Line(np.array([-1.25,1.5,0]),np.array([0.75,-2.5,0])).set_color(BLACK)
#       line5=Line(np.array([-1.,2,0]),np.array([1,-2,0])).set_color(BLACK)
#       line6=Line(np.array([-0.75,2.5,0]),np.array([1.25,-1.5,0])).set_color(BLACK)
#       line7=Line(np.array([-0.5,3,0]),np.array([1.5,-1,0])).set_color(BLACK)
#       line8=Line(np.array([-0.25,3.5,0]),np.array([1.75,-0.5,0])).set_color(BLACK)
#       line9=Line(np.array([0,4,0]),np.array([2,0,0])).set_color(BLACK)
#
#       self.add(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#
#       line1=Line(np.array([-2,0,0]),np.array([0,4,0])).set_color(BLACK)
#       line2=Line(np.array([-1.75,-0.5,0]),np.array([0.25,3.5,0])).set_color(BLACK)
#       line3=Line(np.array([-1.5,-1,0]),np.array([0.5,3,0])).set_color(BLACK)
#       line4=Line(np.array([-1.25,-1.5,0]),np.array([0.75,2.5,0])).set_color(BLACK)
#       line5=Line(np.array([-1,-2,0]),np.array([1,2,0])).set_color(BLACK)
#       line6=Line(np.array([-0.75,-2.5,0]),np.array([1.25,1.5,0])).set_color(BLACK)
#       line7=Line(np.array([-0.5,-3,0]),np.array([1.5,1,0])).set_color(BLACK)
#       line8=Line(np.array([-0.25,-3.5,0]),np.array([1.75,0.5,0])).set_color(BLACK)
#       line9=Line(np.array([0,-4,0]),np.array([2,0,0])).set_color(BLACK)
#       self.add(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#       #self.remove(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#       #grid=NumberPlane()
#       #self.add(grid)
#       line = Line(np.array([-2,0,0]),np.array([-1.5,0,0])).set_color(ORANGE)
#       b1 = Brace(line)
#       b1text = b1.get_text("Horizontal distance").set_color(BLACK)
#       b1text=b1.get_tex("\\bigtriangleup a").set_color(BLACK)
#       #b1text=MathTex("\\bigtriangleup \\a ").set_color(BLACK)
#       b1text=b1text.scale(0.4)
#       #b1text=b1text.shift(LEFT*0.5)
#
#       self.add(line, b1, b1text)
#       line = Line(np.array([-1.75,0.5,0]),np.array([-1.75,-0.5,0])).set_color(PINK)
#       b1 = Brace(line,direction=line.copy().rotate(3*PI / 2).get_unit_vector())
#       b2text=b1.get_tex("2\\bigtriangleup a").set_color(BLACK)
#       b2text=b2text.shift(RIGHT*0.5)
#
#       #b1text=MathTex("\\bigtriangleup \\a ").set_color(BLACK)
#       b2text=b2text.scale(0.4)
#       #b1text=b1text.shift(LEFT*0.5)
#       self.add(line, b1, b1text)
#       self.play(Write(b1text))
#       self.play(Write(b2text))
#
#       #self.play(*[Write(i) for i in zip(b1text,b2text)])
#       self.wait()
#       self.clear()
#       #self.remove_foreground_mobjects(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#       #self.remove(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#       #self.play(FadeOut(img))
#
#       text1=MathTex(
#           "R_{xT}^{\\alpha } =\\frac{1}{T} \\int_{t-(T-\\left | \\tau  \\right | )/2}^{t-(T+\\left | \\tau  \\right | )/2} x(u+\\frac{\\tau }{2} )x^{*} (u-\\frac{\\tau }{2} )e^{-j2\\pi \\alpha u}du ",
#        #   "S_{xT}^{\\alpha } =\\frac{1}{T}X_{T}(t,f+\\frac{\\alpha }{2} ) X_{T}^{*} (t,f-\\frac{\\alpha }{2} )   "
#            # "g(x)\\frac{d}{dx}f(x)"
#         ).set_color(BLACK)
#       text2=MathTex(
#           "S_{xT}^{\\alpha } =\\frac{1}{T}X_{T}(t,f+\\frac{\\alpha }{2} ) X_{T}^{*} (t,f-\\frac{\\alpha }{2} ) "
#       ).set_color(BLACK)
#       group = VGroup(text1, text2)
#       group.arrange(DOWN)
#       right_arrow = MathTex('\\Longrightarrow ').next_to(text2)
#       self.play(Write(text1))
#       self.play(Write(right_arrow))
#       self.play(Write(text2))
#       framebox1 = SurroundingRectangle(text1, buff = .1)
#       framebox2 = SurroundingRectangle(text2, buff = .1)
#       self.play(
#             Create(framebox1),
#         )
#       self.wait()
#       self.play(
#           ReplacementTransform(framebox1,framebox2),
#         )
#       self.wait()
# Out:
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim  -pqm -v WARNING xidianlogo
# config.media_width = "75%"#调节输出MP4/gif大小
# class xidianlogo(Scene):
#     def construct(self):
#       self.camera.background_color = WHITE
#
#       self.camera.background_color = "#ece6e2"
#       #grid=NumberPlane()
#       #self.add(grid)
#       #self.remove_foreground_mobjects(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#       #self.remove(line1,line2,line3,line4,line5,line6,line7,line8,line9)
#       #self.play(FadeOut(img))
#
#       text1=MathTex(
#           "R_{xT}^{\\alpha }(t,\\tau ) =\\frac{1}{T} \\int_{t-(T-\\left | \\tau  \\right | )/2}^{t-(T+\\left | \\tau  \\right | )/2} x(u+\\frac{\\tau }{2} )x^{*} (u-\\frac{\\tau }{2} )e^{-j2\\pi \\alpha u}du ",
#        #   "S_{xT}^{\\alpha } =\\frac{1}{T}X_{T}(t,f+\\frac{\\alpha }{2} ) X_{T}^{*} (t,f-\\frac{\\alpha }{2} )   "
#            # "g(x)\\frac{d}{dx}f(x)"
#         ).set_color(BLACK)
#       text2=MathTex(
#           "S_{xT}^{\\alpha }(t,f) =\\frac{1}{T}X_{T}(t,f+\\frac{\\alpha }{2} ) X_{T}^{*} (t,f-\\frac{\\alpha }{2} ) "
#       ).set_color(BLACK)
#       text3=MathTex(
#           "S_{x}^{\\alpha } (k)=\\frac{1}{N}X(k+\\frac{N\\alpha }{2} ) X^{*} (k-\\frac{N\\alpha }{2} )"
#       ).set_color(BLACK)
#       group = VGroup(text1, text2, text3)
#       group.arrange(DOWN)
#       right_arrow = MathTex('\\Longrightarrow ').next_to(text2).shift(LEFT*10).set_color(BLACK)
#       right_arrow1 = MathTex('\\Longrightarrow ').next_to(text3).shift(LEFT*9).set_color(BLACK)
#       ffttext=Text('FFT').align_to(np.array([-5,0.5,0]),UP).shift(LEFT*5).scale(0.5).set_color(BLACK)
#       adtext=Text('A/D').align_to(np.array([-4.5,-0.8,0]),UP).shift(LEFT*4.5).scale(0.5).set_color(BLACK)
#       self.play(Write(text1))
#       self.play(Write(right_arrow))
#       self.play(Write(ffttext))
#       self.play(Write(text2))
#       self.play(Write(right_arrow1))
#       self.play(Write(adtext))
#       self.play(Write(text3))
#       framebox1 = SurroundingRectangle(text1, buff = .1)
#       framebox2 = SurroundingRectangle(text2, buff = .1)
#       framebox3 = SurroundingRectangle(text3, buff = .1)
#       self.play(
#             Create(framebox1),
#         )
#       self.wait()
#       self.play(
#           ReplacementTransform(framebox1,framebox2),
#         )
#       self.wait()
#       self.play(
#           ReplacementTransform(framebox2,framebox3),
#         )
#       self.wait()
# Out:
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
 # %%manim  -pqm -v WARNING xidianlogo
config.media_width = "75%"#调节输出MP4/gif大小
class xidianlogo(Scene):
    def construct(self):
      self.camera.background_color = WHITE
      
      self.camera.background_color = "#ece6e2"
      #grid=NumberPlane()
      #self.add(grid)
      #self.remove_foreground_mobjects(line1,line2,line3,line4,line5,line6,line7,line8,line9)
      #self.remove(line1,line2,line3,line4,line5,line6,line7,line8,line9)
      #self.play(FadeOut(img))
      text1=MathTex(
          "\\begin{bmatrix}  x(1)&  x(L+1)&  x(2L+1)&  &  x((P-1)L+1)&\\\\  x(2)&  x(L+2)&  x(2L+2)&  &  x((P-1)L+2)&\\\\  \\vdots &  \\vdots &  \\vdots &  \\dots &  \\vdots&\\\\  x(4)&  x(L+N^{'})&  x(2L+N^{'} )&  & x((P-1)L+N^{'} )&\\end{bmatrix}"
      ).set_color(BLACK)
      textm=Text("矩阵维度：").set_color(RED).scale(0.8)
      textn=MathTex("N^{'}\\times  P").set_color(RED)
      group = VGroup(textm, textn)
      group.arrange(RIGHT)
      group.to_edge(DOWN)

      self.play(Write(text1))
      self.play(Write(textm))
      self.play(Write(textn))
      self.wait(1)
      self.clear()
      text2=MathTex(
          "\\begin{bmatrix}  h(1)x(1)&  h(1)x(L+1)&  h(1)x(2L+1)&  &  h(1)x((P-1)L+1)&\\\\  h(2)x(2)&  h(2)x(L+2)&  h(2)x(2L+2)&  &  h(2)x((P-1)L+2)&\\\\  \\vdots &  \\vdots &  \\vdots &  \\dots &  \\vdots&\\\\  h(N^{'})x(4)&  h(N^{'})x(L+N^{'})&  h(N^{'})x(2L+N^{'} )&  & h(N^{'})x((P-1)L+N^{'} )&\\end{bmatrix}"
      ).set_color(BLACK).scale(0.75)
      text2.stretch(1.5,dim=1)
      self.play(Write(text2))
      self.wait(1)
      self.clear()
      text3=MathTex(
          "\\begin{bmatrix}  X_{N^{'}}(0,f_{1} )&  X_{N^{'}}(L,f_{1} )&    &  X_{N^{'}}((P-1)L,f_{1} )&\\\\  X_{N^{'}}(0,f_{2} )&  X_{N^{'}}(L,f_{2} )&    &  X_{N^{'}}((P-1)L,f_{2} )&\\\\  \\vdots &  \\vdots &    \\dots &  \\vdots&\\\\  X_{N^{'}}(0,f_{N^{'} } )&  X_{N^{'}}(L,f_{N^{'}} )&    & X_{N^{'}}((P-1)L,f_{N^{'} } )&\\end{bmatrix}"
      ).set_color(BLACK)
     
      self.play(Write(text3))
      self.wait(1)
      self.clear()
      #grid=NumberPlane()
      #self.add(grid)
      text3=MathTex(
          "\\begin{bmatrix}  X_{N^{'}}(0,f_{1} )&  X_{N^{'}}(L,f_{1} )&    &  X_{N^{'}}((P-1)L,f_{1} )&\\\\  X_{N^{'}}(0,f_{2} )&  X_{N^{'}}(L,f_{2} )&    &  X_{N^{'}}((P-1)L,f_{2} )&\\\\  \\vdots &  \\vdots &    \\dots &  \\vdots&\\\\  X_{N^{'}}(0,f_{N^{'} } )&  X_{N^{'}}(L,f_{N^{'}} )&    & X_{N^{'}}((P-1)L,f_{N^{'} } )&\\end{bmatrix}"
      ).set_color(BLACK)
      text4=MathTex(
          "\\begin{bmatrix}  X_{N^{'}}(0,f_{1} )&  X_{N^{'}}(L,f_{1} )&    &  X_{N^{'}}((P-1)L,f_{1} )&\\\\  X_{N^{'}}(0,f_{2} )&  X_{N^{'}}(L,f_{2} )&    &  X_{N^{'}}((P-1)L,f_{2} )&\\\\  \\vdots &  \\vdots &    \\dots &  \\vdots&\\\\  X_{N^{'}}(0,f_{N^{'} } )&  X_{N^{'}}(L,f_{N^{'}} )&    & X_{N^{'}}((P-1)L,f_{N^{'} } )&\\end{bmatrix}^{*} "
      ).set_color(BLACK).shift(LEFT)
      group = VGroup(text3, text4)
      group.arrange(DOWN)
      rectangle=Rectangle(height=0.6,width=12).shift(UP*2.6).set_color(YELLOW)
      rectangle1=Rectangle(height=0.6,width=12).shift(DOWN*0.4,LEFT*0.1).set_color(YELLOW)
      rectangle2=Rectangle(height=0.6,width=12).shift(DOWN*1,LEFT*0.1).set_color(YELLOW)
      rectangle3=Rectangle(height=0.6,width=12).shift(DOWN*2.6,LEFT*0.3).set_color(YELLOW)
      self.play(Write(text3))
      self.play(Write(text4))
      self.play(Create(rectangle))
      self.play(Create(rectangle1))
      self.play(
          ReplacementTransform(rectangle1,rectangle2),
        )
      self.wait()
      self.play(
          ReplacementTransform(rectangle2,rectangle3),
        )
      textm=Text("运算后矩阵维度：").set_color(RED).scale(0.8)
      textn=MathTex("P\\times (N^{'} )^{2} ").set_color(RED)
      group = VGroup(textm, textn)
      group.arrange(RIGHT)
      group.to_edge(DOWN)
      self.play(Write(textm))
      self.play(Write(textn))
      self.wait()
# Out:
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
text3=MathTex(
          "\\begin{bmatrix}  X_{N^{'}}(0,f_{1} )&  X_{N^{'}}(L,f_{1} )&    &  X_{N^{'}}((P-1)L,f_{1} )&\\\\  X_{N^{'}}(0,f_{2} )&  X_{N^{'}}(L,f_{2} )&    &  X_{N^{'}}((P-1)L,f_{2} )&\\\\  \\vdots &  \\vdots &    \\dots &  \\vdots&\\\\  X_{N^{'}}(0,f_{N^{'} } )&  X_{N^{'}}(L,f_{N^{'}} )&    & X_{N^{'}}((P-1)L,f_{N^{'} } )&\\end{bmatrix}"
      ).set_color(BLACK)

# %%
text3[0][5:14].get_boundary_point(direction=UR)
# Out:
# array([-3.84731315e+00,  1.31645018e+00, -9.45860946e-17])

# %%
text3[0][5:14].get_boundary_point(direction=DR)
# Out:
# array([-3.84731315e+00,  8.18318175e-01, -3.35825186e-17])

# %%
(1.31645018+0.818318175)/2
# Out:
# 1.0673841775

# %%
from manim import Scene

# %%
from manim import *

# %%
# %%manim  -pqm -v WARNING AngleExample
# class AngleExample(Scene):
#             def construct(self):
#                 line1 = Line( LEFT + (1/3) * UP, RIGHT + (1/3) * DOWN )
#                 line2 = Line( DOWN + (1/3) * RIGHT, UP + (1/3) * LEFT )
#                 angles = [
#                     Angle(line1, line2),
#                     Angle(line1, line2, radius=0.4, quadrant=(1,-1), other_angle=True),
#                     Angle(line1, line2, radius=0.5, quadrant=(-1,1), stroke_width=8, other_angle=True),
#                     Angle(line1, line2, radius=0.7, quadrant=(-1,-1), color=RED),
#                     Angle(line1, line2, other_angle=True),
#                     Angle(line1, line2, radius=0.4, quadrant=(1,-1)),
#                     Angle(line1, line2, radius=0.5, quadrant=(-1,1), stroke_width=8),
#                     Angle(line1, line2, radius=0.7, quadrant=(-1,-1), color=RED, other_angle=True),
#                 ]
#                 plots = VGroup()
#                 for angle in angles:
#                     plot=VGroup(line1.copy(),line2.copy(), angle)
#                     plots.add(VGroup(plot,SurroundingRectangle(plot, buff=0.3)))
#                 plots.arrange_in_grid(rows=2,buff=1)
#                 self.add(plots)

# %%
# !manim -pql test.py

# %%
Angle
#回车就可以看到它的位置
#manim.mobject.geometry.Angle
# Out:
# manim.mobject.geometry.Angle

# %%
# !manim -pql scene.py SquareToCircle
# Out:
# Manim Community v0.6.0
#
# [05/10/21 07:07:02] INFO     Animation 0 : Using cached    ]8;id=1620630422.4152167-325062;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              data (hash : 3163782288_40574
#                              19953_3227597104)
#                     INFO     Animation 1 : Using cached    ]8;id=1620630422.4400856-698736;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              data (hash : 1495979052_12974
#                              74700_3227597104)
#                     INFO     Animation 2 : Using cached    ]8;id=1620630422.4634671-833347;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              data (hash : 1495979052_35283
#                              28655_3227597104)
# ...

# %%
# !manim  -iqh scene.py SquareToCircle
# Out:
# Manim Community v0.6.0
#
# [05/10/21 06:17:17] WARNING  --save_as_gif is deprecated, please  ]8;id=1620627437.3367-592117;file:///usr/local/lib/python3.7/dist-packages/manim/cli/render/commands.py\commands.py]8;;\:85
#                              use --format=gif instead!
#                     INFO     Animation 0 : Using cached    ]8;id=1620627437.392176-835067;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              data (hash : 450974505_405741
#                              9953_3227597104)
#                     INFO     Animation 1 : Using cached    ]8;id=1620627437.4287047-865269;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              data (hash : 2788726626_12974
#                              74700_3227597104)
# ...

# %%
# !manim  -iqh scene.py MobjectExample
# Out:
# Manim Community v0.6.0
#
# [05/10/21 06:31:36] WARNING  --save_as_gif is deprecated, please  ]8;id=1620628296.0134947-738431;file:///usr/local/lib/python3.7/dist-packages/manim/cli/render/commands.py\commands.py]8;;\:85
#                              use --format=gif instead!
#                     INFO                                ]8;id=1620628296.813575-820993;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:585
#                              File ready at /content/med
#                              ia/project/media/images/sc
#                              ene/MobjectExample_ManimCE
#                              _v0.6.0.png
#
#                     INFO     Rendered MobjectExample                ]8;id=1620628296.8166144-431438;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:218
#                              Played 0 animations

# %%
! manim -o myscene -i -n 0,10 -c WHITE scene.py SceneName
# Out:
# Manim Community v0.6.0
#
# [05/10/21 07:41:49] WARNING  --save_as_gif is deprecated, please  ]8;id=1620632509.353969-956560;file:///usr/local/lib/python3.7/dist-packages/manim/cli/render/commands.py\commands.py]8;;\:85
#                              use --format=gif instead!
# Traceback (most recent call last):
#   File "/usr/local/bin/manim", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
# ...

# %%
# %cd /content/media/project1
# Out:
# /content/media/project1

# %%
# !manim  -qh customtex.py
# Out:
# Manim Community v0.6.0
#
# 1: InCodeTexTemplate
# 2: TexTemplateFromCLI
#
# Choose number corresponding to desired scene/arguments.
# (Use comma separated list for multiple entries)
# Choice(s):  1
# [05/10/21 07:59:41] INFO     Writing "\vv{vb}" to media/T ]8;id=1620633581.365303-875596;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:81
#                              ex/099b08eeb548472c.tex
# [05/10/21 07:59:44] INFO     Animation 0 : Partial      ]8;id=1620633584.3674176-124185;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:403
#                              movie file written in {'/c
#                              ontent/media/project1/medi
#                              a/videos/customtex/1080p60
#                              /partial_movie_files/InCod
#                              eTexTemplate/450974505_642
#                              269262_2720033552.mp4'}
# ...

# %%
# !manim  -qh zxs.py
# Out:
# Manim Community v0.6.0
#
# [05/10/21 13:23:10] ERROR    LaTeX compilation error!    ]8;id=1620652990.8919861-772331;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:178
#                              latex reports:
#                     ERROR    ! Missing $ inserted.       ]8;id=1620652990.8944604-947551;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:189
#
#                     ERROR    <inserted text>             ]8;id=1620652990.896831-494704;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:189
#
#                     ERROR                    $           ]8;id=1620652990.8990238-220819;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:189
#
# ...

# %%
# !manim  -qh zxs.py
# Out:
# Manim Community v0.6.0
#
# [05/10/21 13:21:09] ERROR    LaTeX compilation error!    ]8;id=1620652869.7069726-303981;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:178
#                              latex reports:
#                     ERROR    ! Missing $ inserted.       ]8;id=1620652869.7093344-60680;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:189
#
#                     ERROR    <inserted text>             ]8;id=1620652869.711613-706762;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:189
#
#                     ERROR                    $           ]8;id=1620652869.7141244-123174;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:189
#
# ...
